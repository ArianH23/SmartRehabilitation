# %%
import pandas as pd

# %%
df = pd.read_csv('data/df.csv')
df
# Out:
#       hand_min_x  hand_min_y  hand_width  hand_height  object_min_x  \
# 0           1032         555         163          178           379
# 1           1032         674         127          155           417
# 2            742         754         126          134          1920
# 3           1055         662         185          172          1433
# 4            987         590         155          153           310
# ...          ...         ...         ...          ...           ...
# 6321        1142         724         123          151             0
# 6322        1127         879         201          192          1077
# 6323        1098         606         220          150             0
# 6324        1134         726         136          146             0
# 6325        1485         413         372          295             0
#
#       object_min_y  object_width  object_height   1x   1y  ...  20x  20y  \
# 0              174           328            349 -345 -385  ... -244 -255
# ...

# %%
last_column = df.pop(df.columns[-1])
df.insert(71, last_column.name, last_column)

# %%
df
# Out:
#       hand_min_x  hand_min_y  hand_width  hand_height  object_min_x  \
# 0           1032         555         163          178           379
# 1           1032         674         127          155           417
# 2            742         754         126          134          1920
# 3           1055         662         185          172          1433
# 4            987         590         155          153           310
# ...          ...         ...         ...          ...           ...
# 6321        1142         724         123          151             0
# 6322        1127         879         201          192          1077
# 6323        1098         606         220          150             0
# 6324        1134         726         136          146             0
# 6325        1485         413         372          295             0
#
#       object_min_y  object_width  object_height   1x   1y  ...  20x  20y  \
# 0              174           328            349 -345 -385  ... -244 -255
# ...

# %%
df.to_csv('data/df_final.csv',index=False)

# %%
df.picture_name.value_counts()
# Out:
# frame_11450.jpg    2
# frame_11226.jpg    2
# frame_10336.jpg    2
# frame_10700.jpg    2
# frame_10708.jpg    2
#                   ..
# frame_9114.jpg     1
# frame_8384.jpg     1
# frame_787.jpg      1
# frame_3266.jpg     1
# frame_10006.jpg    1
# Name: picture_name, Length: 4507, dtype: int64
