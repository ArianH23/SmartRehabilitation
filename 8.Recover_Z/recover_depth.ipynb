# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/salad_yolo_lm_and_z.csv')
df2 = pd.read_csv('data/simu_yolo_lm_and_z.csv')
df_d = pd.read_csv('data/depths_added.csv')

# %%
df = pd.concat([df1, df2],ignore_index=True)

# %%
depth = df_d.iloc[:,-4:-2]
depth
# Out:
#       lh_depth_dist  rh_depth_dist
# 0       -128.411926   -2014.397278
# 1     -10972.939575   -6049.359009
# 2      -3838.286377  -18578.716064
# 3       -814.518860    -905.653381
# 4      -1761.761719   -1246.901855
# ...             ...            ...
# 4753     877.946289    6519.351683
# 4754   -2146.814453    -174.041504
# 4755   -1189.540039    4339.987671
# 4756     901.244385    6482.765343
# 4757    1120.292725    4676.091797
#
# [4758 rows x 2 columns]

# %%
df.iloc[:, :-2]
# Out:
#       l_hand_min_x  l_hand_min_y  l_hand_width  l_hand_height  r_hand_min_x  \
# 0             1920             0             0              0          1001
# 1             1920          1080             0              0          1539
# 2             1171           587           118            168          1920
# 3             1326           521           101             62             0
# 4             1118           351           182            198          1366
# ...            ...           ...           ...            ...           ...
# 4753           972           270           148            176             0
# 4754           877           749           188            121          1003
# 4755           866           400           172            127             0
# 4756          1174           875           123             53             0
# 4757           687           236           153            113             0
#
# ...

# %%
df_f = pd.concat([df.iloc[:, :-2], depth, df.iloc[:,-2:]], axis=1)

# %%
df_f
# Out:
#       l_hand_min_x  l_hand_min_y  l_hand_width  l_hand_height  r_hand_min_x  \
# 0             1920             0             0              0          1001
# 1             1920          1080             0              0          1539
# 2             1171           587           118            168          1920
# 3             1326           521           101             62             0
# 4             1118           351           182            198          1366
# ...            ...           ...           ...            ...           ...
# 4753           972           270           148            176             0
# 4754           877           749           188            121          1003
# 4755           866           400           172            127             0
# 4756          1174           875           123             53             0
# 4757           687           236           153            113             0
#
# ...

# %%
df_f.to_csv('data/depths_and_z.csv',index=False)
